# %% [markdown]
# # Lecture 9 - Partial dependence plots (PDP) in R on COVID data

# %% [markdown]
# ## Set up the data with numeric values

# %%
library(magrittr)

full_data<-sdgm::oncovid %>% dplyr::filter(age_group != "Not Reported")
full_data$age_group<-as.numeric(full_data$age_group)
full_data$gender<-as.numeric(full_data$gender)

head(full_data)
# Out:
#   case_status age_group gender date_reported exposure
# 1 0           4         1      285.4583      Close Contact
# 2 0           1         2      297.4583      Close Contact
# 3 0           5         2      274.4583      Not Reported
# 4 0           2         1      260.4583      Close Contact
# 5 0           3         1      307.5000      Not Reported
# 6 0           4         1      306.5000      Close Contact
#   health_region
# 1 York Region Public Health Services
# 2 York Region Public Health Services
# 3 Peel Public Health
# 4 Halton Region Health Department
# 5 Wellington-Dufferin-Guelph Public Health
# 6 Halton Region Health Department

# %% [markdown]
# ## Show the plot on train data

# %%
voutcome<-"case_status"
# train a model with optimal hyperparameters
best_model<-sdgm::lgbm.bestmodel.bin(full_data, voutcome, tune=F)

v.pdp<-"age_group"
x<-unique(full_data[,v.pdp])
yhat<-sapply(x, function(val)
{
  newdata<-full_data
  newdata[, v.pdp] <- val
  preds<-predict(best_model, newdata)
  mean(preds, na.rm=T)
})

plot.data<-data.frame(yhat=yhat, x=x)
lw1 <- loess(yhat ~ x,data=plot.data)
plot(x, yhat,pch=19,cex=0.1, xlab="age", ylab="p(death)")

j <- order(plot.data$x)
lines(plot.data$x[j],lw1$fitted[j],col="red",lwd=3)
# Out:
# [1] "case_status"   "age_group"     "gender"        "date_reported"
# [5] "exposure"      "health_region"
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038570 -> initscore=-3.215936
# [LightGBM] [Info] Start training from score -3.215936
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038185 -> initscore=-3.226376
# [LightGBM] [Info] Start training from score -3.226376
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.037993 -> initscore=-3.231626
# [LightGBM] [Info] Start training from score -3.231626
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038378 -> initscore=-3.221150
# [LightGBM] [Info] Start training from score -3.221150
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038419 -> initscore=-3.220034
# [LightGBM] [Info] Start training from score -3.220034
# plot without title

# %% [markdown]
# ## Show the plot on test data

# %%
voutcome<-"case_status"

idx<-splitTools::partition(full_data[,voutcome], p=c(train=0.7, test=0.3), type="stratified")
train_data <- full_data[idx$train,] 
test_data <- full_data[idx$test,]

# train a model with optimal hyperparameters
best_model<-sdgm::lgbm.bestmodel.bin(train_data, voutcome, tune=F)

v.pdp<-"age_group"
x<-unique(test_data[,v.pdp])
yhat<-sapply(x, function(val)
{
  newdata<-test_data
  newdata[, v.pdp] <- val
  preds<-predict(best_model, newdata)
  mean(preds, na.rm=T)
})

plot.data<-data.frame(yhat=yhat, x=x)
lw1 <- loess(yhat ~ x,data=plot.data)
plot(x, yhat,pch=19,cex=0.1, xlab="age", ylab="p(death)")

j <- order(plot.data$x)
lines(plot.data$x[j],lw1$fitted[j],col="red",lwd=3)
# Out:
# [1] "case_status"   "age_group"     "gender"        "date_reported"
# [5] "exposure"      "health_region"
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.037453 -> initscore=-3.246499
# [LightGBM] [Info] Start training from score -3.246499
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038415 -> initscore=-3.220122
# [LightGBM] [Info] Start training from score -3.220122
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038435 -> initscore=-3.219591
# [LightGBM] [Info] Start training from score -3.219591
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038317 -> initscore=-3.222782
# [LightGBM] [Info] Start training from score -3.222782
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038887 -> initscore=-3.207443
# [LightGBM] [Info] Start training from score -3.207443
# plot without title
